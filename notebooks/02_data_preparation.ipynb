# %%
# Import and initialize

import sys
sys.path.append('..')

from src.data_processing import DataPreprocessor

# %%
# Use small model for fine-tuning

model_name = "distilbert-base-uncased"
preprocessor = DataPreprocessor(model_name, max_length=256)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
# Process data
# Use subset_size=1000 for quick testing, remove for ful dataset

tokenized_dataset = preprocessor.load_and_prepare_data(
    "imdb",
    subset_size=1000 # Remove this for full dataset
)
# Out:
# Loading imdb...
# Tokenizing the dataset...
# ...
# Map:   0%|          | 0/50000 [00:00<?, ? examples/s]

# %%
# Inspect processed data

print("Tokenized dataset structure:")
print(tokenized_dataset)
print("\nSample tokenized example:")
print(tokenized_dataset['train'][0])
# Out:
# Tokenized dataset structure:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 1000
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 200
#     })
#     unsupervised: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 50000
#     })
# })
#
# Sample tokenized example:
# ...

# %%
# Verify shapes

print(f"\nInput IDs shape: {len(tokenized_dataset['train'][0]['input_ids'])}")
print(f"Attention mask shape: {len(tokenized_dataset['train'][0]['attention_mask'])}")
# Out:
# Input IDs shape: 256
# Attention mask shape: 256
